# %% [markdown]
# #  Pandas PART 2  <a name="part2"></a>

# %% [markdown]
# In Part I you learned about some basic functionalities, how to access contents from your dataframe, indexing, grouping, and how to modify it, making quick plots and even how to create new features based on old ones. In this section, we will go through much of the same material, but more bottom-up, from the very simple data structures to how to efficiently work with them. There will then be some overlap in the material.
#
# <br>- taken from "10 Minutes to pandas"
# (https://pandas.pydata.org/pandas-docs/stable/10min.html)
#
# You can see more complex recipes in the __[Cookbook](https://pandas.pydata.org/pandas-docs/stable/cookbook.html)__
#
# ### höpöhöpö

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# - muistiinpanoja

# %%
# höpöhöpö

??pd.read_csv
# Out:
# Object `pd.read_csv` not found.

# %% [markdown]
# ## Object creation <a name="objectcreation"></a>
#
# See also __[Intro to Data Structures](https://pandas.pydata.org/pandas-docs/stable/dsintro.html)__

# %% [markdown]
# So far we have looked at dataframes. These are analogous to (2D) matrices. The analogy to (1D) vectors are
# __[Series](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.html)__ : a labeled array capable of holding any data type (integers, strings, floating point numbers, Python objects, etc.). The axis labels are collectively referred to as the index.
# Creating a Series by passing a list of values, letting pandas create a default integer index:

# %%
s = pd.Series([1,3,5,np.nan,6,8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %% [markdown]
# Creating a __[DataFrame](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.html)__ by passing a NumPy array, with a datetime index and labeled columns:

# %%
dates = pd.date_range('20130101', periods=6)
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %% [markdown]
# **DataFrame** is a 2-dimensional labeled data structure with columns of potentially different types. You can think of it like a spreadsheet or SQL table, or a dict of Series objects. It is generally the most commonly used pandas object. Like Series, DataFrame accepts many different kinds of input:
#
#  - Dict of 1D ndarrays, lists, dicts, or Series
#  - 2-D numpy.ndarray
#  - [Structured or record ndarray](https://docs.scipy.org/doc/numpy/user/basics.rec.html)
#  - A `Series`
#  - Another `DataFrame`
#
# Along with the data, you can optionally pass **index** (row labels) and **columns** (column labels) arguments. If you pass an index and / or columns, you are guaranteeing the index and / or columns of the resulting DataFrame.

# %%
df = pd.DataFrame(np.random.randn(6,4), index=dates, columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2013-01-01 -0.498515 -1.014382  1.918604  0.639550
# 2013-01-02  0.296242  1.219187 -0.196412 -0.030096
# 2013-01-03 -0.788618 -0.189270  0.685237 -0.705269
# 2013-01-04 -0.305166 -0.314970 -0.579938 -0.655821
# 2013-01-05  0.749447 -0.627843 -1.858634 -0.534845
# 2013-01-06  1.160068 -0.056420  0.680754  0.010408

# %% [markdown]
# Creating a DataFrame by passing a dict of objects that can be converted to series-like

# %%
df2 = pd.DataFrame({ 'A' : 1.,
                    'B' : pd.Timestamp('20130102'),
                    'C' : pd.Series(1,index=list(range(4)),dtype='float32'),
                    'D' : np.array([3] * 4,dtype='int32'),
                    'E' : pd.Categorical(["test","train","test","train"]),
                    'F' : 'foo' })
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %% [markdown]
# The columns of the resulting DataFrame have different dtypes.

# %%
df2.dtypes
# Out:
# A          float64
# B    datetime64[s]
# C          float32
# D            int32
# E         category
# F           object
# dtype: object

# %% [markdown]
# If you’re using IPython (Jupyter notebook), tab completion for column names (as well as public attributes) is automatically enabled, ie.  df2.`<TAB>` <br> Here’s a subset of the attributes that will be completed:

# %% [markdown]
# ```python
# df2.<TAB>
#
#  df2.A     df2.E       df2.add            df2.aggregate   df2.append        df2.as_matrix
#  df2.B     df2.F       df2.add_prefix     df2.align       df2.apply         df2.asfreq
#  df2.C     df2.T       df2.add_suffix     df2.all         df2.applymap      df2.asof       >
#  df2.D     df2.abs     df2.agg            df2.any         df2.as_blocks     df2.assign
# ```

# %% [markdown]
# As you can see, the columns `A`, `B`, `C`, and `D` are automatically tab completed. `E` is there as well; the rest of the attributes have been truncated for brevity.

# %% [markdown]
# ## Viewing Data <a name="viewing"></a>

# %% [markdown]
# Here is how to view the top and bottom rows of the frame:

# %%
df.head()
# Out:
#                    A         B         C         D
# 2013-01-01 -0.498515 -1.014382  1.918604  0.639550
# 2013-01-02  0.296242  1.219187 -0.196412 -0.030096
# 2013-01-03 -0.788618 -0.189270  0.685237 -0.705269
# 2013-01-04 -0.305166 -0.314970 -0.579938 -0.655821
# 2013-01-05  0.749447 -0.627843 -1.858634 -0.534845

# %%
df.tail()
# Out:
#                    A         B         C         D
# 2013-01-02  0.296242  1.219187 -0.196412 -0.030096
# 2013-01-03 -0.788618 -0.189270  0.685237 -0.705269
# 2013-01-04 -0.305166 -0.314970 -0.579938 -0.655821
# 2013-01-05  0.749447 -0.627843 -1.858634 -0.534845
# 2013-01-06  1.160068 -0.056420  0.680754  0.010408

# %% [markdown]
# Display the index, columns, and the underlying NumPy data:

# %%
df.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.values
# Out:
# array([[-0.49851525, -1.01438204,  1.91860432,  0.63954982],
#        [ 0.29624182,  1.21918716, -0.19641157, -0.03009607],
#        [-0.78861805, -0.18927014,  0.68523708, -0.70526941],
#        [-0.30516605, -0.3149701 , -0.5799379 , -0.65582072],
#        [ 0.74944675, -0.62784282, -1.85863417, -0.53484451],
#        [ 1.16006753, -0.05642042,  0.68075449,  0.01040807]])

# %% [markdown]
# `describe()` shows a quick statistic summary of your data:

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.102243 -0.163950  0.108269 -0.212679
# std    0.761055  0.759804  1.294072  0.520040
# min   -0.788618 -1.014382 -1.858634 -0.705269
# 25%   -0.450178 -0.549625 -0.484056 -0.625577
# 50%   -0.004462 -0.252120  0.242171 -0.282470
# 75%    0.636146 -0.089633  0.684116  0.000282
# max    1.160068  1.219187  1.918604  0.639550

# %% [markdown]
# ## Selection <a name="selection"></a>

# %% [markdown]
# See also the indexing documentation __[Indexing and Selecting Data](https://pandas.pydata.org/pandas-docs/stable/indexing.html)__
# and  __[MultiIndex / Advanced Indexing](https://pandas.pydata.org/pandas-docs/stable/advanced.html)__

# %% [markdown]
# #### Getting

# %% [markdown]
# Selecting a single column, which yields a Series, equivalent to `df.A`

# %%
df['A']
# Out:
# 2013-01-01   -0.498515
# 2013-01-02    0.296242
# 2013-01-03   -0.788618
# 2013-01-04   -0.305166
# 2013-01-05    0.749447
# 2013-01-06    1.160068
# Freq: D, Name: A, dtype: float64

# %% [markdown]
# Selecting via `[]`, which slices the rows

# %%
df[0:3]
# Out:
#                    A         B         C         D
# 2013-01-01 -0.498515 -1.014382  1.918604  0.639550
# 2013-01-02  0.296242  1.219187 -0.196412 -0.030096
# 2013-01-03 -0.788618 -0.189270  0.685237 -0.705269

# %% [markdown]
# #### Selection by Label

# %% [markdown]
# For more, see __[Selection by Label](https://pandas.pydata.org/pandas-docs/stable/indexing.html)__

# %%
# For getting a cross section using a label

df.loc[dates[0]]
# Out:
# A   -0.498515
# B   -1.014382
# C    1.918604
# D    0.639550
# Name: 2013-01-01 00:00:00, dtype: float64

# %%
# Selecting on a multi-axis by label

df.loc[:,['A','B']]
# Out:
#                    A         B
# 2013-01-01 -0.498515 -1.014382
# 2013-01-02  0.296242  1.219187
# 2013-01-03 -0.788618 -0.189270
# 2013-01-04 -0.305166 -0.314970
# 2013-01-05  0.749447 -0.627843
# 2013-01-06  1.160068 -0.056420

# %%
# Showing label slicing, both endpoints are included

df.loc['20130102':'20130104',['A','B']]
# Out:
#                    A         B
# 2013-01-02  0.296242  1.219187
# 2013-01-03 -0.788618 -0.189270
# 2013-01-04 -0.305166 -0.314970

# %%
# Reduction in the dimensions of the returned object

df.loc['20130102',['A','B']]
# Out:
# A    0.296242
# B    1.219187
# Name: 2013-01-02 00:00:00, dtype: float64

# %%
# For getting a scalar value

df.loc[dates[0],'A']
# Out:
# np.float64(-0.4985152496688454)

# %%
# For getting fast access to a scalar (equivalent to the prior method)

df.at[dates[0],'A']
# Out:
# np.float64(-0.4985152496688454)

# %% [markdown]
# #### Selection by Position

# %% [markdown]
# See more in __[Selection by Position](https://pandas.pydata.org/pandas-docs/stable/indexing.html)__

# %% [markdown]
# Select via the position of the passed integers

# %%
df.iloc[3]
# Out:
# A   -0.305166
# B   -0.314970
# C   -0.579938
# D   -0.655821
# Name: 2013-01-04 00:00:00, dtype: float64

# %% [markdown]
# By integer slices, acting similar to numpy/python

# %%
df.iloc[3:5,0:2]
# Out:
#                    A         B
# 2013-01-04 -0.305166 -0.314970
# 2013-01-05  0.749447 -0.627843

# %% [markdown]
# By lists of integer position locations, similar to the numpy/python style

# %%
df.iloc[[1,2,4],[0,2]]
# Out:
#                    A         C
# 2013-01-02  0.296242 -0.196412
# 2013-01-03 -0.788618  0.685237
# 2013-01-05  0.749447 -1.858634

# %% [markdown]
# For slicing rows explicitly

# %%
df.iloc[1:3,:]
# Out:
#                    A         B         C         D
# 2013-01-02  0.296242  1.219187 -0.196412 -0.030096
# 2013-01-03 -0.788618 -0.189270  0.685237 -0.705269

# %% [markdown]
# For slicing columns explicitly

# %%
df.iloc[:,1:3]
# Out:
#                    B         C
# 2013-01-01 -1.014382  1.918604
# 2013-01-02  1.219187 -0.196412
# 2013-01-03 -0.189270  0.685237
# 2013-01-04 -0.314970 -0.579938
# 2013-01-05 -0.627843 -1.858634
# 2013-01-06 -0.056420  0.680754

# %% [markdown]
# For getting a value explicitly

# %%
df.iloc[1,1]
# Out:
# np.float64(1.2191871583534901)

# %% [markdown]
# For getting fast access to a scalar (equivalent to the prior method)

# %%
df.iat[1,1]
# Out:
# np.float64(1.2191871583534901)

# %% [markdown]
# #### Boolean Indexing

# %% [markdown]
# Using a single column’s values to select data

# %%
df[df.A > 0]
# Out:
#                    A         B         C         D
# 2013-01-02  0.296242  1.219187 -0.196412 -0.030096
# 2013-01-05  0.749447 -0.627843 -1.858634 -0.534845
# 2013-01-06  1.160068 -0.056420  0.680754  0.010408

# %% [markdown]
# Selecting values from a DataFrame where a boolean condition is met

# %%
df[df > 0]
# Out:
#                    A         B         C         D
# 2013-01-01       NaN       NaN  1.918604  0.639550
# 2013-01-02  0.296242  1.219187       NaN       NaN
# 2013-01-03       NaN       NaN  0.685237       NaN
# 2013-01-04       NaN       NaN       NaN       NaN
# 2013-01-05  0.749447       NaN       NaN       NaN
# 2013-01-06  1.160068       NaN  0.680754  0.010408

# %% [markdown]
# Using the `isin()` method for filtering

# %%
df2 = df.copy()
df2['E'] = ['one', 'one','two','three','four','three']
df2
# Out:
#                    A         B         C         D      E
# 2013-01-01 -0.498515 -1.014382  1.918604  0.639550    one
# 2013-01-02  0.296242  1.219187 -0.196412 -0.030096    one
# 2013-01-03 -0.788618 -0.189270  0.685237 -0.705269    two
# 2013-01-04 -0.305166 -0.314970 -0.579938 -0.655821  three
# 2013-01-05  0.749447 -0.627843 -1.858634 -0.534845   four
# 2013-01-06  1.160068 -0.056420  0.680754  0.010408  three

# %%
df2[df2['E'].isin(['two','four'])]
# Out:
#                    A         B         C         D     E
# 2013-01-03 -0.788618 -0.189270  0.685237 -0.705269   two
# 2013-01-05  0.749447 -0.627843 -1.858634 -0.534845  four

# %% [markdown]
# #### Setting

# %% [markdown]
# Setting a new column automatically aligns the data by the indexes

# %%
s1 = pd.Series([1,2,3,4,5,6], index=pd.date_range('20130102', periods=6))
s1
# Out:
# 2013-01-02    1
# 2013-01-03    2
# 2013-01-04    3
# 2013-01-05    4
# 2013-01-06    5
# 2013-01-07    6
# Freq: D, dtype: int64

# %%
df['F'] = s1
df
# Out:
#                    A         B         C         D    F
# 2013-01-01 -0.498515 -1.014382  1.918604  0.639550  NaN
# 2013-01-02  0.296242  1.219187 -0.196412 -0.030096  1.0
# 2013-01-03 -0.788618 -0.189270  0.685237 -0.705269  2.0
# 2013-01-04 -0.305166 -0.314970 -0.579938 -0.655821  3.0
# 2013-01-05  0.749447 -0.627843 -1.858634 -0.534845  4.0
# 2013-01-06  1.160068 -0.056420  0.680754  0.010408  5.0

# %% [markdown]
# Setting values by label

# %%
df.at[dates[0],'A'] = 0
df
# Out:
#                    A         B         C         D    F
# 2013-01-01  0.000000 -1.014382  1.918604  0.639550  NaN
# 2013-01-02  0.296242  1.219187 -0.196412 -0.030096  1.0
# 2013-01-03 -0.788618 -0.189270  0.685237 -0.705269  2.0
# 2013-01-04 -0.305166 -0.314970 -0.579938 -0.655821  3.0
# 2013-01-05  0.749447 -0.627843 -1.858634 -0.534845  4.0
# 2013-01-06  1.160068 -0.056420  0.680754  0.010408  5.0

# %% [markdown]
# Setting values by position

# %%
df.iat[0,1] = 0
df
# Out:
#                    A         B         C         D    F
# 2013-01-01  0.000000  0.000000  1.918604  0.639550  NaN
# 2013-01-02  0.296242  1.219187 -0.196412 -0.030096  1.0
# 2013-01-03 -0.788618 -0.189270  0.685237 -0.705269  2.0
# 2013-01-04 -0.305166 -0.314970 -0.579938 -0.655821  3.0
# 2013-01-05  0.749447 -0.627843 -1.858634 -0.534845  4.0
# 2013-01-06  1.160068 -0.056420  0.680754  0.010408  5.0

# %% [markdown]
# Setting by assigning with a NumPy array

# %%
df.loc[:,'D'] = np.array([5] * len(df))

# %% [markdown]
# The result of the prior setting operations

# %%
df
# Out:
#                    A         B         C    D    F
# 2013-01-01  0.000000  0.000000  1.918604  5.0  NaN
# 2013-01-02  0.296242  1.219187 -0.196412  5.0  1.0
# 2013-01-03 -0.788618 -0.189270  0.685237  5.0  2.0
# 2013-01-04 -0.305166 -0.314970 -0.579938  5.0  3.0
# 2013-01-05  0.749447 -0.627843 -1.858634  5.0  4.0
# 2013-01-06  1.160068 -0.056420  0.680754  5.0  5.0

# %% [markdown]
# A `where` operation with setting

# %%
df2 = df.copy()
df2[df2 > 0] = -df2
df2
# Out:
#                    A         B         C    D    F
# 2013-01-01  0.000000  0.000000 -1.918604 -5.0  NaN
# 2013-01-02 -0.296242 -1.219187 -0.196412 -5.0 -1.0
# 2013-01-03 -0.788618 -0.189270 -0.685237 -5.0 -2.0
# 2013-01-04 -0.305166 -0.314970 -0.579938 -5.0 -3.0
# 2013-01-05 -0.749447 -0.627843 -1.858634 -5.0 -4.0
# 2013-01-06 -1.160068 -0.056420 -0.680754 -5.0 -5.0

# %% [markdown]
# ## Missing data <a name="missing"></a>

# %% [markdown]
# Pandas primarily uses the value `np.nan` to represent missing data. It is by default not included in computations. See the __[Missing Data section](https://pandas.pydata.org/pandas-docs/stable/missing_data.html)__

# %% [markdown]
# Reindexing allows you to change/add/delete the index on a specified axis. This returns a copy of the data

# %%
df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ['E'])
df1.loc[dates[0]:dates[1],'E'] = 1
df1
# Out:
#                    A         B         C    D    F    E
# 2013-01-01  0.000000  0.000000  1.918604  5.0  NaN  1.0
# 2013-01-02  0.296242  1.219187 -0.196412  5.0  1.0  1.0
# 2013-01-03 -0.788618 -0.189270  0.685237  5.0  2.0  NaN
# 2013-01-04 -0.305166 -0.314970 -0.579938  5.0  3.0  NaN

# %% [markdown]
# To drop any rows that have missing data

# %%
df1.dropna(how='any')
# Out:
#                    A         B         C    D    F    E
# 2013-01-02  0.296242  1.219187 -0.196412  5.0  1.0  1.0

# %% [markdown]
# Filling missing data

# %%
df1.fillna(value=5)
# Out:
#                    A         B         C    D    F    E
# 2013-01-01  0.000000  0.000000  1.918604  5.0  5.0  1.0
# 2013-01-02  0.296242  1.219187 -0.196412  5.0  1.0  1.0
# 2013-01-03 -0.788618 -0.189270  0.685237  5.0  2.0  5.0
# 2013-01-04 -0.305166 -0.314970 -0.579938  5.0  3.0  5.0

# %% [markdown]
# To get the boolean mask where values are `nan`

# %%
pd.isna(df1)
# Out:
#                 A      B      C      D      F      E
# 2013-01-01  False  False  False  False   True  False
# 2013-01-02  False  False  False  False  False  False
# 2013-01-03  False  False  False  False  False   True
# 2013-01-04  False  False  False  False  False   True

# %% [markdown]
# ## Operations <a name="operations"></a>

# %% [markdown]
# See the __[Basic section on Binary Ops](https://pandas.pydata.org/pandas-docs/stable/basics.html)__

# %% [markdown]
# #### Stats

# %% [markdown]
# Operations in general *exclude* missing data

# %% [markdown]
# Performing a descriptive statistic

# %%
df.mean()
# Out:
# A    0.185329
# B    0.005114
# C    0.108269
# D    5.000000
# F    3.000000
# dtype: float64

# %% [markdown]
# Same operation on the other axis

# %%
df.mean(1)
# Out:
# 2013-01-01    1.729651
# 2013-01-02    1.463803
# 2013-01-03    1.341470
# 2013-01-04    1.359985
# 2013-01-05    1.452594
# 2013-01-06    2.356880
# Freq: D, dtype: float64

# %% [markdown]
# Operating with objects that have different dimensionality and need alignment. In addition, pandas automatically broadcasts along the specified dimension

# %%
s = pd.Series([1,3,5,np.nan,6,8], index=dates).shift(2)
s
# Out:
# 2013-01-01    NaN
# 2013-01-02    NaN
# 2013-01-03    1.0
# 2013-01-04    3.0
# 2013-01-05    5.0
# 2013-01-06    NaN
# Freq: D, dtype: float64

# %%
df.sub(s, axis='index')
# Out:
#                    A         B         C    D    F
# 2013-01-01       NaN       NaN       NaN  NaN  NaN
# 2013-01-02       NaN       NaN       NaN  NaN  NaN
# 2013-01-03 -1.788618 -1.189270 -0.314763  4.0  1.0
# 2013-01-04 -3.305166 -3.314970 -3.579938  2.0  0.0
# 2013-01-05 -4.250553 -5.627843 -6.858634  0.0 -1.0
# 2013-01-06       NaN       NaN       NaN  NaN  NaN

# %% [markdown]
# #### Apply

# %% [markdown]
# Applying functions to the data

# %%
df.apply(np.cumsum)
# Out:
#                    A         B         C     D     F
# 2013-01-01  0.000000  0.000000  1.918604   5.0   NaN
# 2013-01-02  0.296242  1.219187  1.722193  10.0   1.0
# 2013-01-03 -0.492376  1.029917  2.407430  15.0   3.0
# 2013-01-04 -0.797542  0.714947  1.827492  20.0   6.0
# 2013-01-05 -0.048096  0.087104 -0.031142  25.0  10.0
# 2013-01-06  1.111972  0.030684  0.649612  30.0  15.0

# %%
df.apply(lambda x: x.max() - x.min())
# Out:
# A    1.948686
# B    1.847030
# C    3.777238
# D    0.000000
# F    4.000000
# dtype: float64

# %% [markdown]
# #### Histogramming

# %% [markdown]
# See more at __[Histogramming and Discretization](https://pandas.pydata.org/pandas-docs/stable/basics.html)__

# %%
s = pd.Series(np.random.randint(0, 7, size=10)); s
# Out:
# 0    1
# 1    2
# 2    1
# 3    0
# 4    2
# 5    5
# 6    5
# 7    1
# 8    0
# 9    0
# dtype: int64

# %%
s.value_counts()
# Out:
# 1    3
# 0    3
# 2    2
# 5    2
# Name: count, dtype: int64

# %% [markdown]
# #### String Methods

# %% [markdown]
# Series is equipped with a set of string processing methods in the str attribute that make it easy to operate on each element of the array, as in the code snippet below. Note that pattern-matching in str generally uses regular expressions by default (and in some cases always uses them). <br>
# See more at __[Vectorized String Methods](https://pandas.pydata.org/pandas-docs/stable/text.html)__

# %%
s = pd.Series(['A', 'B', 'C', 'Aaba', 'Baca', np.nan, 'CABA', 'dog', 'cat'])
s.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: object

# %% [markdown]
# ## Merging  <a name="merging"></a>

# %% [markdown]
# #### Concat

# %% [markdown]
# pandas provides various facilities for easily combining together Series, DataFrame, and Panel objects with various kinds of set logic for the indexes and relational algebra functionality in the case of join / merge-type operations.<br>
# See the __[Merging section](https://pandas.pydata.org/pandas-docs/stable/merging.html)__

# %% [markdown]
# Concatenating pandas objects together with `concat()`:

# %%
df = pd.DataFrame(np.random.randn(10, 4)); df
# Out:
#           0         1         2         3
# 0 -0.206049 -2.286579  0.578824  0.078534
# 1 -0.732487  0.383425 -1.182476 -1.000078
# 2 -1.263327  1.077119  0.749810  1.293189
# 3  0.279763  0.035857  0.933661 -1.244278
# 4  0.429767 -0.346956 -1.700371  0.505953
# 5  0.199874 -0.821777  1.355713 -1.671695
# 6  1.414879  0.062935 -1.615218 -0.544551
# 7  0.144665  0.494655  0.786096  0.282684
# 8 -0.027624  0.861381 -1.266329 -1.472076
# 9 -1.576948 -0.030275 -0.345685  1.140474

# %%
# break it into pieces
pieces = [df[:3], df[3:7], df[7:]]
pieces
# Out:
# [          0         1         2         3
#  0 -0.206049 -2.286579  0.578824  0.078534
#  1 -0.732487  0.383425 -1.182476 -1.000078
#  2 -1.263327  1.077119  0.749810  1.293189,
#            0         1         2         3
#  3  0.279763  0.035857  0.933661 -1.244278
#  4  0.429767 -0.346956 -1.700371  0.505953
#  5  0.199874 -0.821777  1.355713 -1.671695
#  6  1.414879  0.062935 -1.615218 -0.544551,
#            0         1         2         3
#  7  0.144665  0.494655  0.786096  0.282684
#  8 -0.027624  0.861381 -1.266329 -1.472076
#  9 -1.576948 -0.030275 -0.345685  1.140474]

# %%
 pd.concat(pieces)
# Out:
#           0         1         2         3
# 0 -0.206049 -2.286579  0.578824  0.078534
# 1 -0.732487  0.383425 -1.182476 -1.000078
# 2 -1.263327  1.077119  0.749810  1.293189
# 3  0.279763  0.035857  0.933661 -1.244278
# 4  0.429767 -0.346956 -1.700371  0.505953
# 5  0.199874 -0.821777  1.355713 -1.671695
# 6  1.414879  0.062935 -1.615218 -0.544551
# 7  0.144665  0.494655  0.786096  0.282684
# 8 -0.027624  0.861381 -1.266329 -1.472076
# 9 -1.576948 -0.030275 -0.345685  1.140474

# %% [markdown]
# #### Join

# %% [markdown]
# SQL style merges. See the __[Database style joining](https://pandas.pydata.org/pandas-docs/stable/merging.html)__ section

# %%
left = pd.DataFrame({'key': ['bar', 'foo'], 'lval': [1, 2]})
right = pd.DataFrame({'key': ['foo', 'bar','bar'], 'rval': [4, 5, 6]})

print('left:\n', left)
print('\nright:\n', right)
# Out:
# left:
#     key  lval
# 0  bar     1
# 1  foo     2
#
# right:
#     key  rval
# 0  foo     4
# 1  bar     5
# 2  bar     6

# %%
pd.merge(left, right, on='key')
# Out:
#    key  lval  rval
# 0  bar     1     5
# 1  bar     1     6
# 2  foo     2     4

# %% [markdown]
# #### Append

# %% [markdown]
# Append rows to a dataframe. See the __[Appending](https://pandas.pydata.org/pandas-docs/stable/merging.html)__ section.

# %%
df = pd.DataFrame(np.random.randn(8, 4), columns=['A','B','C','D']); df
# Out:
#           A         B         C         D
# 0  0.044675  1.649222  0.986588 -0.959388
# 1  0.395784  1.184579  2.049870  0.005912
# 2 -2.317578 -0.896300  0.674905 -1.670639
# 3 -1.382128 -0.812605  1.505311  1.489150
# 4 -0.079915 -0.381661  0.241538  0.429713
# 5 -1.473151 -1.350888 -2.457368 -0.589132
# 6  2.908385 -0.684316 -1.307984  0.804126
# 7 -1.279074 -2.303649  0.327396 -0.262365

# %%
s = df.iloc[3]; s
# Out:
# A   -1.382128
# B   -0.812605
# C    1.505311
# D    1.489150
# Name: 3, dtype: float64

# %%
df.append(s, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/00/6012pj094t96h6swnqrvhsz80000gn/T/ipykernel_23321/4011806271.py in ?()
# ----> 1 df.append(s, ignore_index=True)
#
# /opt/anaconda3/envs/test_env/lib/python3.13/site-packages/pandas/core/generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
df = pd.concat([df, s.to_frame().T], ignore_index=True)
df
# Out:
#           A         B         C         D
# 0  0.044675  1.649222  0.986588 -0.959388
# 1  0.395784  1.184579  2.049870  0.005912
# 2 -2.317578 -0.896300  0.674905 -1.670639
# 3 -1.382128 -0.812605  1.505311  1.489150
# 4 -0.079915 -0.381661  0.241538  0.429713
# 5 -1.473151 -1.350888 -2.457368 -0.589132
# 6  2.908385 -0.684316 -1.307984  0.804126
# 7 -1.279074 -2.303649  0.327396 -0.262365
# 8 -1.382128 -0.812605  1.505311  1.489150
# 9 -1.382128 -0.812605  1.505311  1.489150

# %% [markdown]
# ## Grouping  <a name="grouping"></a>

# %% [markdown]
# By “group by” we are referring to a process involving one or more of the following steps:
#
#  - **Splitting** the data into groups based on some criteria
#  - **Applying** a function to each group independently
#  - **Combining** the results into a data structure
#
# See the __[Grouping section](https://pandas.pydata.org/pandas-docs/stable/groupby.html)__

# %%
df = pd.DataFrame({'A' : ['foo', 'bar', 'foo', 'bar',
                          'foo', 'bar', 'foo', 'foo'],
                   'B' : ['one', 'one', 'two', 'three',
                          'two', 'two', 'one', 'three'],
                   'C' : np.random.randn(8),
                   'D' : np.random.randn(8)})
df
# Out:
#      A      B         C         D
# 0  foo    one -0.927864  0.170726
# 1  bar    one -1.022272 -0.604972
# 2  foo    two  1.208460  0.968758
# 3  bar  three  0.868528 -1.506551
# 4  foo    two -1.162737 -0.624331
# 5  bar    two -0.828618 -0.538870
# 6  foo    one  0.300773 -0.711107
# 7  foo  three  2.146525 -0.820531

# %% [markdown]
# Grouping and then applying the `min()` function to the resulting groups

# %%
df.groupby('A').min()
# Out:
#        B         C         D
# A
# bar  one -1.022272 -1.506551
# foo  one -1.162737 -0.820531

# %% [markdown]
# Grouping by multiple columns forms a hierarchical index, and again we can apply the `min()` function

# %%
df.groupby(['A','B']).min()
# Out:
#                   C         D
# A   B
# bar one   -1.022272 -0.604972
#     three  0.868528 -1.506551
#     two   -0.828618 -0.538870
# foo one   -0.927864 -0.711107
#     three  2.146525 -0.820531
#     two   -1.162737 -0.624331

# %% [markdown]
# ## Reshaping  <a name="reshaping"></a>

# %% [markdown]
# See the sections on __[Hierarchical Indexing](https://pandas.pydata.org/pandas-docs/stable/advanced.html#advanced-hierarchical)__ and __[Reshaping](https://pandas.pydata.org/pandas-docs/stable/reshaping.html#reshaping-stacking)__

# %% [markdown]
# #### Stack

# %%
tuples = list(zip(*[['bar', 'bar', 'baz', 'baz',
                      'foo', 'foo', 'qux', 'qux'],
                     ['one', 'two', 'one', 'two',
                      'one', 'two', 'one', 'two']]))
tuples
# Out:
# [('bar', 'one'),
#  ('bar', 'two'),
#  ('baz', 'one'),
#  ('baz', 'two'),
#  ('foo', 'one'),
#  ('foo', 'two'),
#  ('qux', 'one'),
#  ('qux', 'two')]

# %%
index = pd.MultiIndex.from_tuples(tuples, names=['first', 'second'])
index
# Out:
# MultiIndex([('bar', 'one'),
#             ('bar', 'two'),
#             ('baz', 'one'),
#             ('baz', 'two'),
#             ('foo', 'one'),
#             ('foo', 'two'),
#             ('qux', 'one'),
#             ('qux', 'two')],
#            names=['first', 'second'])

# %%
df = pd.DataFrame(np.random.randn(8, 2), index=index, columns=['A', 'B']); df
# Out:
#                      A         B
# first second
# bar   one     0.499318 -1.327138
#       two    -1.125080 -2.310550
# baz   one    -0.069761 -0.631505
#       two    -0.483452 -0.666397
# foo   one    -0.649642  0.543119
#       two     1.033764 -1.984224
# qux   one     0.236052 -0.488283
#       two     0.458105 -1.948105

# %%
df2 = df[:4]
df2
# Out:
#                      A         B
# first second
# bar   one     0.499318 -1.327138
#       two    -1.125080 -2.310550
# baz   one    -0.069761 -0.631505
#       two    -0.483452 -0.666397

# %% [markdown]
# The __[stack()](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.stack.html#pandas.DataFrame.stack)__ method “compresses” a level in the DataFrame’s columns

# %%
stacked = df2.stack()
stacked
# Out:
# first  second
# bar    one     A    0.499318
#                B   -1.327138
#        two     A   -1.125080
#                B   -2.310550
# baz    one     A   -0.069761
#                B   -0.631505
#        two     A   -0.483452
#                B   -0.666397
# dtype: float64

# %% [markdown]
# With a “stacked” DataFrame or Series (having a MultiIndex as the index), the inverse operation of stack() is __[unstack()](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.unstack.html#pandas.DataFrame.unstack)__, which by default unstacks the **last level**:

# %%
stacked.unstack()
# Out:
#                      A         B
# first second
# bar   one     0.499318 -1.327138
#       two    -1.125080 -2.310550
# baz   one    -0.069761 -0.631505
#       two    -0.483452 -0.666397

# %%
stacked.unstack(1)
# Out:
# second        one       two
# first
# bar   A  0.499318 -1.125080
#       B -1.327138 -2.310550
# baz   A -0.069761 -0.483452
#       B -0.631505 -0.666397

# %%
stacked.unstack(0)
# Out:
# first          bar       baz
# second
# one    A  0.499318 -0.069761
#        B -1.327138 -0.631505
# two    A -1.125080 -0.483452
#        B -2.310550 -0.666397

# %% [markdown]
# #### Pivot Tables

# %% [markdown]
# See the section on __[Pivot Tables](https://pandas.pydata.org/pandas-docs/stable/reshaping.html#reshaping-pivot)__

# %%
df = pd.DataFrame({'A' : ['one', 'one', 'two', 'three'] * 3,
                    'B' : ['A', 'B', 'C'] * 4,
                    'C' : ['foo', 'foo', 'foo', 'bar', 'bar', 'bar'] * 2,
                    'D' : np.random.randn(12),
                    'E' : np.random.randn(12)})
df
# Out:
#         A  B    C         D         E
# 0     one  A  foo  1.748639 -0.446586
# 1     one  B  foo -0.918395  0.305308
# 2     two  C  foo -1.825893  0.686206
# 3   three  A  bar -0.292003  0.521753
# 4     one  B  bar  0.719020 -1.264099
# 5     one  C  bar  0.273831 -0.723494
# 6     two  A  foo  0.306518 -0.182391
# 7   three  B  foo  0.822775 -0.823848
# 8     one  C  foo  0.503044 -1.001277
# 9     one  A  bar  0.662142 -0.708800
# 10    two  B  bar  0.467611  1.953657
# 11  three  C  bar -0.093109  0.898302

# %% [markdown]
# We can produce pivot tables from this data very easily:

# %%
pd.pivot_table(df, values='D', index=['A', 'B'], columns=['C'])
# Out:
# C             bar       foo
# A     B
# one   A  0.662142  1.748639
#       B  0.719020 -0.918395
#       C  0.273831  0.503044
# three A -0.292003       NaN
#       B       NaN  0.822775
#       C -0.093109       NaN
# two   A       NaN  0.306518
#       B  0.467611       NaN
#       C       NaN -1.825893

# %% [markdown]
# ## Categoricals <a name="categoricals"></a>

# %% [markdown]
# Pandas can include categorical data in a `DataFrame`. For full docs, see the __[categorical introduction](https://pandas.pydata.org/pandas-docs/stable/categorical.htm)__ and the __[API documentation](https://pandas.pydata.org/pandas-docs/stable/api.html)__

# %%
df = pd.DataFrame({"id":[1,2,3,4,5,6], "raw_grade":['a', 'b', 'b', 'a', 'a', 'e']})
df
# Out:
#    id raw_grade
# 0   1         a
# 1   2         b
# 2   3         b
# 3   4         a
# 4   5         a
# 5   6         e

# %% [markdown]
# Convert the raw grades to a categorical data type

# %%
df["grade"] = df["raw_grade"].astype("category")
df["grade"]
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: grade, dtype: category
# Categories (3, object): ['a', 'b', 'e']

# %% [markdown]
# Rename the categories to more meaningful names (assigning to `Series.cat.categories` is inplace!)

# %%
df["grade"].cat.categories = ["very good", "good", "very bad"]
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 df["grade"].cat.categories = ["very good", "good", "very bad"]
#       2 df
#
# File /opt/anaconda3/envs/test_env/lib/python3.13/site-packages/pandas/core/base.py:179, in NoNewAttributesMixin.__setattr__(self, key, value)
#     173 if getattr(self, "__frozen", False) and not (
#     174     key == "_cache"
#     175     or key in type(self).__dict__
#     176     or getattr(self, key, None) is not None
#     177 ):
#     178     raise AttributeError(f"You cannot add any new attribute '{key}'")
# --> 179 object.__setattr__(self, key, value)
#
# File /opt/anaconda3/envs/test_env/lib/python3.13/site-packages/pandas/core/accessor.py:99, in PandasDelegate._add_delegate_accessors.<locals>._create_delegator_property.<locals>._setter(self, new_values)
#      98 def _setter(self, new_values):
# ---> 99     return self._delegate_property_set(name, new_values)
#
# File /opt/anaconda3/envs/test_env/lib/python3.13/site-packages/pandas/core/arrays/categorical.py:2956, in CategoricalAccessor._delegate_property_set(self, name, new_values)
#    2955 def _delegate_property_set(self, name: str, new_values):  # type: ignore[override]
# -> 2956     return setattr(self._parent, name, new_values)
#
# AttributeError: property 'categories' of 'Categorical' object has no setter

# %%
mapping = {
    "a": "very good",
    "b": "good",
    "e": "very bad"
}

df["grade"] = (
    df["raw_grade"]
    .map(mapping)
    .astype("category")
)

df
# Out:
#    id raw_grade      grade
# 0   1         a  very good
# 1   2         b       good
# 2   3         b       good
# 3   4         a  very good
# 4   5         a  very good
# 5   6         e   very bad

# %% [markdown]
# Reorder the categories and simultaneously add the missing categories (methods under `Series .cat` return a new `Series` by default)

# %%
df["grade"] = df["grade"].cat.set_categories(["very bad", "bad", "medium", "good", "very good"])
df["grade"]
# Out:
# 0    very good
# 1         good
# 2         good
# 3    very good
# 4    very good
# 5     very bad
# Name: grade, dtype: category
# Categories (5, object): ['very bad', 'bad', 'medium', 'good', 'very good']

# %% [markdown]
# Sorting is per order in the categories, not lexical order

# %%
df.sort_values(by="grade")
# Out:
#    id raw_grade      grade
# 5   6         e   very bad
# 1   2         b       good
# 2   3         b       good
# 0   1         a  very good
# 3   4         a  very good
# 4   5         a  very good

# %% [markdown]
# Grouping by a categorical column also shows empty categories

# %%
df.groupby("grade").size()
# Out:
# /var/folders/00/6012pj094t96h6swnqrvhsz80000gn/T/ipykernel_23321/3951628473.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby("grade").size()
# grade
# very bad     1
# bad          0
# medium       0
# good         2
# very good    3
# dtype: int64

# %% [markdown]
# ## Plotting <a name="plotting"></a>

# %% [markdown]
# See the __[Plotting docs](https://pandas.pydata.org/pandas-docs/stable/visualization.html)__

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))
ts = ts.cumsum()
ts.plot()
# Out:
# <Axes: >

# %% [markdown]
# On a DataFrame, the `plot()` method is a convenience to plot all of the columns with labels

# %%
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index,
columns=['A', 'B', 'C', 'D']) 

df = df.cumsum()
plt.figure(); df.plot(); plt.legend(loc='best')

# %% [markdown]
# ## Getting Data In/Out <a name="datainout"></a>

# %%
import tables # pytables is needed to read and write hdf5 files
import openpyxl # is used to read and write MS Excel files

# %%
pip install tables
# Out:
# Collecting tables
#   Downloading tables-3.10.2-cp313-cp313-macosx_11_0_arm64.whl.metadata (2.0 kB)
# Requirement already satisfied: numpy>=1.20.0 in /opt/anaconda3/envs/test_env/lib/python3.13/site-packages (from tables) (2.3.5)
# Collecting numexpr>=2.6.2 (from tables)
#   Downloading numexpr-2.14.1-cp313-cp313-macosx_11_0_arm64.whl.metadata (9.0 kB)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/test_env/lib/python3.13/site-packages (from tables) (26.0)
# Collecting py-cpuinfo (from tables)
#   Downloading py_cpuinfo-9.0.0-py3-none-any.whl.metadata (794 bytes)
# Collecting blosc2>=2.3.0 (from tables)
#   Downloading blosc2-4.0.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (7.6 kB)
# Requirement already satisfied: typing-extensions>=4.4.0 in /opt/anaconda3/envs/test_env/lib/python3.13/site-packages (from tables) (4.15.0)
# Collecting ndindex (from blosc2>=2.3.0->tables)
#   Downloading ndindex-1.10.1-cp313-cp313-macosx_11_0_arm64.whl.metadata (3.6 kB)
# Collecting msgpack (from blosc2>=2.3.0->tables)
#   Downloading msgpack-1.1.2-cp313-cp313-macosx_11_0_arm64.whl.metadata (8.1 kB)
# Requirement already satisfied: requests in /opt/anaconda3/envs/test_env/lib/python3.13/site-packages (from blosc2>=2.3.0->tables) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/test_env/lib/python3.13/site-packages (from requests->blosc2>=2.3.0->tables) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/test_env/lib/python3.13/site-packages (from requests->blosc2>=2.3.0->tables) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/test_env/lib/python3.13/site-packages (from requests->blosc2>=2.3.0->tables) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/test_env/lib/python3.13/site-packages (from requests->blosc2>=2.3.0->tables) (2026.1.4)
# Downloading tables-3.10.2-cp313-cp313-macosx_11_0_arm64.whl (5.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 2.8 MB/s  0:00:01 eta 0:00:01
# Downloading blosc2-4.0.0-cp313-cp313-macosx_11_0_arm64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 3.0 MB/s  0:00:01 eta 0:00:01
# Downloading numexpr-2.14.1-cp313-cp313-macosx_11_0_arm64.whl (152 kB)
# Downloading msgpack-1.1.2-cp313-cp313-macosx_11_0_arm64.whl (84 kB)
# Downloading ndindex-1.10.1-cp313-cp313-macosx_11_0_arm64.whl (175 kB)
# Downloading py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Installing collected packages: py-cpuinfo, numexpr, ndindex, msgpack, blosc2, tables
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [tables]2m5/6 [tables]]
# Successfully installed blosc2-4.0.0 msgpack-1.1.2 ndindex-1.10.1 numexpr-2.14.1 py-cpuinfo-9.0.0 tables-3.10.2
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [openpyxl]1/2 [openpyxl]
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #### CSV

# %% [markdown]
# [`Writing to a csv file`](https://pandas.pydata.org/pandas-docs/stable/io.html#io-store-in-csv)

# %%
df.to_csv('./testdata/foo.csv')

# %% [markdown]
# [`Reading from a csv file`](https://pandas.pydata.org/pandas-docs/stable/io.html#io-read-csv-table)

# %%
pd.read_csv('./testdata/foo.csv').head()
# Out:
#    Unnamed: 0         A         B         C         D
# 0  2000-01-01  2.302505 -0.158921 -0.261727  0.048900
# 1  2000-01-02  1.571730  0.686474  0.150579  1.448166
# 2  2000-01-03  2.161502  1.237174 -0.645131  0.839198
# 3  2000-01-04  3.521721  0.850151 -0.685074  2.607541
# 4  2000-01-05  3.272728  0.444510 -0.370546  3.063653

# %% [markdown]
# To get help on __read_csv__, type: `read_csv?`

# %%
# read_csv?

# %% [markdown]
# #### HDF5

# %% [markdown]
# Reading and writing to [`HDFStores`](https://pandas.pydata.org/pandas-docs/stable/io.html#io-hdf5)

# %% [markdown]
# Writing to a HDF5 Store

# %%
# pytables is needed
df.to_hdf('./testdata/foo.h5','df')
# Out:
# /var/folders/00/6012pj094t96h6swnqrvhsz80000gn/T/ipykernel_23321/281057014.py:2: FutureWarning: Starting with pandas version 3.0 all arguments of to_hdf except for the argument 'path_or_buf' will be keyword-only.
#   df.to_hdf('./testdata/foo.h5','df')

# %% [markdown]
# Reading from a HDF5 Store

# %%
pd.read_hdf('./testdata/foo.h5','df').head()
# Out:
#                    A         B         C         D
# 2000-01-01  2.302505 -0.158921 -0.261727  0.048900
# 2000-01-02  1.571730  0.686474  0.150579  1.448166
# 2000-01-03  2.161502  1.237174 -0.645131  0.839198
# 2000-01-04  3.521721  0.850151 -0.685074  2.607541
# 2000-01-05  3.272728  0.444510 -0.370546  3.063653

# %% [markdown]
# #### Excel

# %% [markdown]
# Reading and writing to [`MS Excel`](https://pandas.pydata.org/pandas-docs/stable/io.html#io-excel)

# %% [markdown]
# Writing to an excel file

# %%
# openpyxl is needed
df.to_excel('./testdata/foo.xlsx', sheet_name='Sheet1')

# %% [markdown]
# Reading from an excel file

# %%
pd.read_excel('./testdata/foo.xlsx', 'Sheet1', index_col=None, na_values=['NA']).head()
# Out:
#   Unnamed: 0         A         B         C         D
# 0 2000-01-01  2.302505 -0.158921 -0.261727  0.048900
# 1 2000-01-02  1.571730  0.686474  0.150579  1.448166
# 2 2000-01-03  2.161502  1.237174 -0.645131  0.839198
# 3 2000-01-04  3.521721  0.850151 -0.685074  2.607541
# 4 2000-01-05  3.272728  0.444510 -0.370546  3.063653

# %% [markdown]
# ## Going further <a name="going"></a>
#
# -  A handy Pandas *cheat sheet*:  http://pandas.pydata.org/Pandas_Cheat_Sheet.pdf
# -  Pandas: .head() to .tail() https://www.youtube.com/watch?v=7vuO9QXDN50  (1:26) <br>
#     w/GitHub repo: https://github.com/TomAugspurger/pydata-chi-h2t
# -  Very instructive tutorials:  http://pandas.pydata.org/pandas-docs/stable/tutorials.html
